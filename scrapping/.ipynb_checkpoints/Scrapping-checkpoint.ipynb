# %%
import numpy as np
import pandas as pd

import time
import json
import yaml

import tweepy

# %%
with open('../config.yaml', 'r') as f:
    config = yaml.safe_load(f)

# %%
twitter_config = config.get('twitter')

# %%
APP_KEY = twitter_config.get('APP_KEY')
APP_SECRET = twitter_config.get('APP_SECRET')
OAUTH_TOKEN = twitter_config.get('OAUTH_TOKEN')
OAUTH_TOKEN_SECRET = twitter_config.get('OAUTH_TOKEN_SECRET')

# %%
def authenticate(api_key, secret_key, access_token, secret_token):

    auth = tweepy.OAuthHandler(api_key, secret_key)
    auth.set_access_token(access_token, secret_token)
    api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
  
    return api

# %%
api = authenticate(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

# %%
def get_tweets(api, user_id):
    cur_users = []
    cur_tweets = []
    
    tweets = api.user_timeline(id=user_id, tweet_mode="extended", count=200)
    
    for tweet in tweets:
        if((not tweet.retweeted) and ('RT @' not in tweet.full_text)):
            continue
        else:
            cur_tweets.append(tweet.full_text)
            cur_users.append(user_id)

    return cur_users, cur_tweets

# %%
users_id = []
tweets = []

# %%
data = pd.read_csv("twitter_ID.csv")
data.head()
# Out:
#                                    Full Name Twitter Username Twitter  \
# 0                                            BEM ITS          BEM_ITS
# 1  Institut Teknologi Sepuluh Nopember | ITS Sura...       its_campus
# 2                                        ITS Library  PerpustakaanITS
# 3                            Lembaga Minat Bakat ITS          LMB_ITS
# 4                                       ITS Robotics     ITS_Robotics
#
#    Twitter ID
# 0    75362544
# 1   306613537
# 2  2713719181
# 3   502525735
# 4  2613707857

# %%
for tid in data["Twitter ID"]:
    cur_users, cur_tweets = get_tweets(api, tid)
    users_id.extend(cur_users)
    tweets.extend(cur_tweets)

# %%
new_df = pd.DataFrame({"user_id": users_id, "tweet": tweets})

# %%
new_df
# Out:
#                                                   tweet    user_id
# 0     SURABAYA ENVIRONMENTAL TALKSHOW by ENVIRONATIO...   75362544
# 1     Sebuah Persembahan untuk Sepuluh Nopember! \n\...   75362544
# 2     Untuk informasi lebih lanjut, kunjungi:\nLine@...   75362544
# 3     CLOSING MANIFEST 2019\n\nHalo KM ITS!\n\nDatan...   75362544
# 4     Go grabs yours!\nPresale 2 tickets only 60.000...   75362544
# 5     PARADIGM ISE 2019\n\nISE 2019 Proudly Present:...   75362544
# 6     Dengan komitmen global, mari kita bersama menj...   75362544
# 7     Perserikatan Bangsa-Bangsa berulangtahun ke 74...   75362544
# 8     Tiket bisa di beli https://t.co/Mlxw4rxZMD, go...   75362544
# 9     SCHEMATICS REEVA\n\nHalo KM ITS! \n\nKonser mu...   75362544
# 10    Line | Ig : @schematics.its\nTwitter | Ask : @...   75362544
# 11    Jadilah bagian dari revolusi dengan membeli ti...   75362544
# 12    Kamu bisa mendapatkan total SKEM 400 jika kamu...   75362544
# 13    SCHEMATICS NATIONAL SEMINAR OF TECHNOLOGY (NST...   75362544
# 14    Narahubung:\nNike Besta - (0822-2895-8301)\nEm...   75362544
# 15    Untuk jadwal pelatihan dan informasi lebih lan...   75362544
# 16    Halo KM ITS!\n\nAda info menarik untuk kalian ...   75362544
# 17    Halo KM ITS!\n\nAda info menarik dari nih! \nC...   75362544
# 18    RT @perfectstarnger: @BEM_ITS Jangan lupa samp...   75362544
# 19    RT @Rogo_Jagad: @BEM_ITS Semangat rek yang aks...   75362544
# 20    RT @eddybroadcaster: @BEM_ITS Ingat Surabaya a...   75362544
# 21    RT @KuchinkLine: KUCHINK AE BUDAL MOSOK KON NG...   75362544
# 22    RT @hafiidhaqqu: Yow iki suroboyo ojo meneng a...   75362544
# 23    RT @somasanubari: gas terus! https://t.co/qKUY...   75362544
# 24    Seruan langsung kpd semua rakyat &amp; mahasis...   75362544
# 25    Terdapat sejumlah poin krusial yg melemahkan K...   75362544
# 26    SISA 4 KURSI! SAHABAT IELTS SURABAYA BATCH 2, ...   75362544
# 27    IELTS PREDICTION TEST\n\nCashback 200rb IELTS ...   75362544
# 28    Hai @bem_unpad,\nHati-hati di jalan, rek! \nKe...   75362544
# 29    Halo KM ITS! \n\nDitengah keramaian isu-isu ya...   75362544
# ...                                                 ...        ...
# 3951  || Live Report Final NLC 2018 ||\n\nHalo, Sche...  197740648
# 3952  || Live Report Final NPC 2018 ||\n\nHalo, Sche...  197740648
# 3953  || Finalis NLC 2018 ||\n\nHalo, Schematist!🤗\n...  197740648
# 3954  || Finalis NLC 2018 ||\n\nHalo, Schematist!🤗\n...  197740648
# 3955  || Finalis NLC 2018 ||\n\nHalo, Schematist!🤗\n...  197740648
# 3956  || Live Report Final NPC 2018 ||\n\nHalo, Sche...  197740648
# 3957  || Selamat Berjuang Lagi Besok ||\n\nHalo, Sch...  197740648
# 3958  || Live Report Perempat Final NLC 2018 ||\n\nH...  197740648
# 3959  || Live Report Perdelapan Final NLC 2018 ||\n\...  197740648
# 3960  || Live Report Perdelapan Final NLC 2018 ||\n\...  197740648
# 3961     @jinko_chan halo, silahkan cek di website ya 😀  197740648
# 3962  || Live Report Perdelapan Final NLC 2018 ||\n\...  197740648
# 3963  || Live Report Perdelapan Final NLC 2018 ||\n\...  197740648
# 3964  || Pengumuman Penyisihan NLC 2018 ||\n\nHalo, ...  197740648
# 3965  || CHALLENGE SCHEMATICS NST ||\n\nApakah kalia...  197740648
# 3966  || CHALLENGE SCHEMATICS NST ||\n\nApakah kalia...  197740648
# 3967  || Pre-Sale #2 ||\n\nHai Schematist!🤗\n\nSeger...  197740648
# 3968  || Seminar dari Schematics ||\n\nHai, Schemati...  197740648
# 3969  || Pre-Sale #2 REEVA Masih Ada 🔥 ||\n\nHalo Sc...  197740648
# 3970  RT @askmenfess: [askmf] hai ada yg tau jawaban...  197740648
# 3971  || Finalis NPC 2018 ||\n\nHalo, Schematist! 🤗\...  197740648
# 3972  || Live Report NLC 2018 ||\n\nHalo, Schematist...  197740648
# 3973  || Live Report NLC 2018 ||\n\nHalo, Schematist...  197740648
# 3974  || Live Report NLC 2018 ||\n\nHalo, Schematist...  197740648
# 3975  || Live Report NLC 2018 ||\n\nHalo, Schematist...  197740648
# 3976  || Live Report NLC 2018 ||\n\nHalo, Schematist...  197740648
# 3977  @Azhar_Fahri661 hallo, ada nama region di web ...  197740648
# 3978  || H-1 Penyisihan NLC ||\n\nHalo Schematist! 🤗...  197740648
# 3979  || H-2 Penyisihan NLC ||\n\nHalo Schematist! 🤗...  197740648
# 3980  || BE A PART OF SCHEMATICS 2018 ||\n\nHalo, Sc...  197740648
#
# [3981 rows x 2 columns]
